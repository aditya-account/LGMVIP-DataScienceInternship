# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-account/LGMVIP-DataScienceInternship/blob/main/ImageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LGMVIP_DS_November_Task
# #Beginner level Task-4
# #Image to Pencil Sketch with Python
# #By: Aditya Dhanraj Shivkar

# %%
import numpy as np
import pandas as pd

import cv2 as cv
from google.colab.patches import cv2_imshow #image display
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt
import urllib.request

# %%
image= io.imread("/content/drive/MyDrive/huskyImage.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=936x527 at 0x7F22C4FCD510>

# %%
grey_filter=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv2_imshow(grey_filter)
# Out:
# <PIL.Image.Image image mode=L size=936x527 at 0x7F22C4FCD690>

# %%
invert=cv.bitwise_not(grey_filter)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=936x527 at 0x7F22C2EF4810>

# %%
blur=cv.GaussianBlur(invert,(21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=936x527 at 0x7F22C2EF0290>

# %%
invertedblur=cv.bitwise_not(blur)
cv2_imshow(invertedblur)
# Out:
# <PIL.Image.Image image mode=L size=936x527 at 0x7F22C2EF03D0>

# %%
sketch_filter=cv.divide(grey_filter,invertedblur,scale=255.0)
cv2_imshow(sketch_filter)
cv.imwrite("sketch.jpg",sketch_filter)
# Out:
# <PIL.Image.Image image mode=L size=936x527 at 0x7F22C2EF5750>
# True
